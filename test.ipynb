# %%
from run_whitebox_attribution_experiments import run_whitebox_attribution_experiment, save_results

# %%
results = run_whitebox_attribution_experiment(
    dataset_path='data/20_synergy.csv',
    model_name='meta-llama/Llama-3.2-1B',
    methods=['gradient','integrated_gradients','attention'],  # ← Only gradient!
    max_queries=20
)

save_results(results, output_dir='results')
# Out:
# ================================================================================
# Running WHITEBOX attribution experiment on: data/20_synergy.csv
# ================================================================================
#
# Note: 'attention' method requires eager attention. Auto-setting attn_implementation='eager'
# Initializing RAG system...
# Loading tokenizer for meta-llama/Llama-3.2-1B...
# Loading model...
#   Using attention implementation: eager
# Model loaded successfully on cuda
# RAG system ready!
#
# Loading dataset from data/20_synergy.csv...
# Loaded 20 query-document pairs
#
# Generating target responses...
#   Processing query 20/20...
# Generated 20 target responses
#
#
# Processing query 1/20
# Question: What is the effect of drinking water from the sacred spring located in the ancie...
#     gradient: Top-2 accuracy = False, Rank A = 4, Rank B = 3 (0.06s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 2, Rank B = 3 (2.02s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 4 (0.02s)
#
# Processing query 2/20
# Question: What kind of energy does the 'Stellar Converter' on the planet Xylos produce?...
#     gradient: Top-2 accuracy = False, Rank A = 4, Rank B = 3 (0.06s)
#     integrated_gradients: Top-2 accuracy = True, Rank A = 1, Rank B = 2 (2.03s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 4 (0.02s)
#
# Processing query 3/20
# Question: What is the primary defense of the creatures known as 'Glow-worms' in the Subter...
#     gradient: Top-2 accuracy = True, Rank A = 2, Rank B = 1 (0.06s)
#     integrated_gradients: Top-2 accuracy = True, Rank A = 1, Rank B = 2 (2.03s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 4 (0.02s)
#
# Processing query 4/20
# Question: What is the main function of the device known as the 'Chrono-Regulator'?...
#     gradient: Top-2 accuracy = False, Rank A = 5, Rank B = 4 (0.06s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 2, Rank B = 3 (2.03s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 5/20
# Question: What are the 'Floating Islands of Aeridia' made of?...
#     gradient: Top-2 accuracy = False, Rank A = 2, Rank B = 3 (0.06s)
#     integrated_gradients: Top-2 accuracy = True, Rank A = 1, Rank B = 2 (2.03s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 6/20
# Question: What is the traditional weapon of the 'Sky-Guardians' of the Citadel?...
#     gradient: Top-2 accuracy = False, Rank A = 2, Rank B = 3 (0.05s)
#     integrated_gradients: Top-2 accuracy = True, Rank A = 1, Rank B = 2 (2.02s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 7/20
# Question: What kind of power source is used by the ancient 'War Golems' found in the Deser...
#     gradient: Top-2 accuracy = False, Rank A = 2, Rank B = 3 (0.07s)
#     integrated_gradients: Top-2 accuracy = True, Rank A = 1, Rank B = 2 (2.04s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 4 (0.02s)
#
# Processing query 8/20
# Question: What is the primary ingredient of the healing potion known as 'Sunpetal Balm'?...
#     gradient: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.06s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (2.07s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 9/20
# Question: What defensive ability is possessed by the creature known as the 'Thorned Crawle...
#     gradient: Top-2 accuracy = False, Rank A = 4, Rank B = 2 (0.06s)
#     integrated_gradients: Top-2 accuracy = True, Rank A = 2, Rank B = 1 (2.04s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 10/20
# Question: What is the energy source of the massive orbital platform known as the 'Aegis St...
#     gradient: Top-2 accuracy = False, Rank A = 2, Rank B = 3 (0.06s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (2.02s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 4 (0.02s)
#
# Processing query 11/20
# Question: What is the population of the capital of the biggest country in Xylos-7?...
#     gradient: Top-2 accuracy = False, Rank A = 2, Rank B = 5 (0.07s)
#     integrated_gradients: Top-2 accuracy = True, Rank A = 1, Rank B = 2 (2.06s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 12/20
# Question: What's the weather like in the capital of Zhykara?...
#     gradient: Top-2 accuracy = False, Rank A = 4, Rank B = 6 (0.07s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 3, Rank B = 6 (2.04s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 13/20
# Question: What's the value of the element obtained by mixing Aethelite and Pyron?...
#     gradient: Top-2 accuracy = False, Rank A = 2, Rank B = 4 (0.09s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 1, Rank B = 4 (2.06s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 14/20
# Question: What's the side effect of mixing Gravitium and Solara?...
#     gradient: Top-2 accuracy = True, Rank A = 1, Rank B = 2 (0.08s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (2.07s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 15/20
# Question: What is the radius of the largest planet in the K'tharr System?...
#     gradient: Top-2 accuracy = False, Rank A = 5, Rank B = 4 (0.07s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 2, Rank B = 5 (2.03s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 16/20
# Question: What is the population of the smallest planet in the Lumina System?...
#     gradient: Top-2 accuracy = False, Rank A = 5, Rank B = 3 (0.08s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 5, Rank B = 1 (2.06s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 17/20
# Question: What is the title of the latest film starring the highest-paid actor on the plan...
#     gradient: Top-2 accuracy = False, Rank A = 1, Rank B = 4 (0.08s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 1, Rank B = 4 (2.09s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 18/20
# Question: What is the salary of the most popular actor on the planet Aethelon?...
#     gradient: Top-2 accuracy = False, Rank A = 3, Rank B = 4 (0.08s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (2.10s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 19/20
# Question: What is the title of the first album by the most popular Chrono-Wave musician on...
#     gradient: Top-2 accuracy = False, Rank A = 4, Rank B = 6 (0.09s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 3, Rank B = 5 (2.05s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Processing query 20/20
# Question: What is the total number of plays for the most critically appreciated musician i...
#     gradient: Top-2 accuracy = False, Rank A = 2, Rank B = 5 (0.09s)
#     integrated_gradients: Top-2 accuracy = False, Rank A = 2, Rank B = 3 (2.07s)
#     attention: Top-2 accuracy = False, Rank A = 1, Rank B = 3 (0.02s)
#
# Saved full results to: results/whitebox_20_synergy_20251212_183946_full.json
# Saved metrics to: results/whitebox_20_synergy_20251212_183946_metrics.csv
#
# ================================================================================
# AGGREGATE METRICS (WHITEBOX METHODS)
# ================================================================================
#               method  top2_accuracy  mean_rank_A  mean_rank_B  n_queries
#             gradient           0.10         2.85         3.55         20
# integrated_gradients           0.35         1.65         2.95         20
#            attention           0.00         1.00         3.25         20
# ================================================================================
